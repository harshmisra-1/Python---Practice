# %%
# %matplotlib inline

import numpy as np
from pylab import *

def de_mean(x):
    xmean = mean(x)
    return [xi - xmean for xi in x]

def covariance(x, y):
    n = len(x)
    return dot(de_mean(x), de_mean(y)) / (n-1)

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = np.random.normal(50.0, 10.0, 1000)

scatter(pageSpeeds, purchaseAmount)

covariance (pageSpeeds, purchaseAmount)
# Out:
# -0.050875951871378965

# %% [markdown]
# Taking purchase amount as a function of page speed and understanding a negative relation

# %%
purchaseAmount = np.random.normal(50.0, 10.0, 1000) / pageSpeeds

scatter(pageSpeeds, purchaseAmount)

covariance (pageSpeeds, purchaseAmount)
# Out:
# -7.885509082493275

# %%
def correlation(x, y):
    stddevx = x.std()
    stddevy = y.std()
    return covariance(x,y) / stddevx / stddevy  #In real life you'd check for divide by zero here

correlation(pageSpeeds, purchaseAmount)
# Out:
# -0.5176019639472259

# %%
np.corrcoef(pageSpeeds, purchaseAmount)
# Out:
# array([[ 1.        , -0.51708436],
#        [-0.51708436,  1.        ]])

# %%
np.cov(pageSpeeds, purchaseAmount)
# Out:
# array([[  0.97305272,  -7.88550908],
#        [ -7.88550908, 239.00131684]])

# %% [markdown]
# Converting it to a linear relation between page Speed and Purchase Amount

# %%
purchaseAmount = 100 - pageSpeeds * 3

scatter(pageSpeeds, purchaseAmount)

correlation (pageSpeeds, purchaseAmount)
# Out:
# -1.001001001001001

# %%
np.cov(pageSpeeds, purchaseAmount)
# Out:
# array([[ 0.97305272, -2.91915816],
#        [-2.91915816,  8.75747449]])
