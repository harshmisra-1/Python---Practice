# %%
# %matplotlib inline
from scipy.stats import norm
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv("/Users/harshmisra/Downloads/FuelEfficiency.csv")
plt.plot(df['CombMPG'],'r:')
plt.show()

# %%
plt.xkcd()

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.xkcd()

plt.plot(df['Transmission'])

# %%
plt.rcdefaults()
colors = ['r', 'g', 'b', 'c', 'm']
explode = [0,0,0.2,0,0,0]
#Types = [df.split()[-1] for x in df]
Cylinder_counts = df['Cylinders'].value_counts()
plt.pie(Cylinder_counts, colors= colors,explode = explode)
plt.show()

# %%
x = np.arange(-4, 15, 0.01)

plt.plot(x, norm.pdf(x,4,2))
plt.show()

# %%
df.head()
# Out:
#               Mfr Name     Carline  Eng Displ  Cylinders Transmission  \
# 0         aston martin  Vantage V8        4.0          8     Auto(S8)
# 1  Volkswagen Group of      Chiron        8.0         16  Auto(AM-S7)
# 2       General Motors    CORVETTE        6.2          8     Auto(S8)
# 3       General Motors    CORVETTE        6.2          8     Auto(S8)
# 4       General Motors    CORVETTE        6.2          8     Auto(S8)
#
#    CityMPG  HwyMPG  CombMPG  # Gears
# 0       18      25       21        8
# 1        9      14       11        7
# 2       12      20       15        8
# 3       15      25       18        8
# 4       14      23       17        8

# %%
plt.plot(x, norm.pdf(x))
plt.plot(x, norm.pdf(x, 1.0, 0.5))

# %%
values = [12, 55, 40, 32, 14]
colors = ['r', 'g', 'b', 'c', 'm']
explode = [0, 0, 0.2, 0, 0]
labels = ['India', 'United States', 'Russia', 'China', 'Europe']
plt.pie(values, colors= colors, labels=labels, explode = explode)
plt.title('Student Locations')
plt.show()
