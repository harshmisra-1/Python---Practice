# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_excel('/Users/harshmisra/Downloads//cars.xls')
import seaborn as sns
sns.set()
df.head()
# Out:
#           Price  Mileage   Make    Model      Trim   Type  Cylinder  Liter  \
# 0  17314.103129     8221  Buick  Century  Sedan 4D  Sedan         6    3.1
# 1  17542.036083     9135  Buick  Century  Sedan 4D  Sedan         6    3.1
# 2  16218.847862    13196  Buick  Century  Sedan 4D  Sedan         6    3.1
# 3  16336.913140    16342  Buick  Century  Sedan 4D  Sedan         6    3.1
# 4  16339.170324    19832  Buick  Century  Sedan 4D  Sedan         6    3.1
#
#    Doors  Cruise  Sound  Leather
# 0      4       1      1        1
# 1      4       1      1        0
# 2      4       1      1        0
# 3      4       1      0        0
# 4      4       1      0        1

# %%
Type_counts = df['Type'].value_counts()
Type_counts.plot(kind='bar')

# %%
Cylinder_counts = df['Cylinder'].value_counts()
Cylinder_counts.plot(kind='bar')

# %%
fig, axs = plt.subplots(1,2)
sns.distplot(df['Price'],ax=axs[0])
sns.distplot(df['Mileage'],ax=axs[1])

# %%
sns.pairplot(df, hue= 'Cylinder', height=2.5);

# %%
sns.scatterplot(x="Price", y="Mileage", data=df)

# %%
sns.lmplot(x="Price", y="Mileage", data=df)

# %%
sns.set(rc={'figure.figsize':(15,5)})
ax = sns.boxplot(x='Cylinder', y='Price', data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# Out:
# [Text(0, 0, '4'), Text(0, 0, '6'), Text(0, 0, '8')]

# %%
sns.set(rc={'figure.figsize':(15,5)})
ax = sns.boxplot(x='Cylinder', y='Mileage', data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# Out:
# [Text(0, 0, '4'), Text(0, 0, '6'), Text(0, 0, '8')]

# %%
sns.set(rc={'figure.figsize':(15,5)})
ax = sns.boxplot(x='Doors', y='Price', data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# Out:
# [Text(0, 0, '2'), Text(0, 0, '4')]

# %%
# %matplotlib inline
import numpy as np
df1=df[['Mileage','Price']]
bins =  np.arange(0,50000,10000)
groups = df1.groupby(pd.cut(df1['Mileage'],bins)).mean()
print(groups)
groups['Price'].plot.line()
# Out:
#                      Mileage         Price
# Mileage
# (0, 10000]       5588.629630  24096.714451
# (10000, 20000]  15898.496183  21955.979607
# (20000, 30000]  24114.407104  20278.606252
# (30000, 40000]  33610.338710  19463.670267

# %%
sns.boxplot(df['Price'])

# %%
bins
# Out:
# array([    0, 10000, 20000, 30000, 40000])

# %%
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

X = df[['Mileage', 'Cylinder', 'Doors']]
y = df['Price']

X[['Mileage', 'Cylinder', 'Doors']] = scale.fit_transform(X[['Mileage', 'Cylinder', 'Doors']].as_matrix())

print (X)
print(y)

est = sm.OLS(y, X).fit()

est.summary()
# Out:
# /Users/harshmisra/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# /Users/harshmisra/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/harshmisra/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#       Mileage  Cylinder     Doors
# 0   -1.417485  0.527410  0.556279
# ...

# %%
y.groupby(df.Doors).mean()
# Out:
# Doors
# 2    23807.135520
# 4    20580.670749
# Name: Price, dtype: float64

# %%
scaled = scale.transform([[1000, 8, 4]])
print(scaled)
predicted = est.predict(scaled[0])
print(predicted)
# Out:
# [[-2.29903873  1.96971667  0.55627894]]
# [13149.52734098]

# %% [markdown]
# Majorly Cylinders infulence the prices of the cars
